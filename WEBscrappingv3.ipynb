# %% [markdown]
# <a href="https://colab.research.google.com/github/jucasel/Projecte-Machine-Learning/blob/main/WEBscrappingv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)

print(page.text)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL de la página (reemplázala por la URL real si es pública)
url = 'https://www.lnphn.com/estadisticas-totales-2/'

# Realizar la solicitud GET para obtener el contenido HTML de la página
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Encontrar la tabla por su clase
table = soup.find('table', {'class': 'table table-hover table-standings sp-league-table sp-data-table sp-sortable-table sp-scrollable-table dataTable no-footer'})

# Inicializar listas para almacenar los datos
players_data = {
    "Jugador": [],
    "Goles": [],
    "Asistencias": [],
    "Disparos Totales": [],
    "Disparos a Portería": [],
    "Disparos fuera del Area": [],
    "Vallas Invictas": [],
    "Faltas Cometidas": [],
    "Faltas Recibidas": [],
    "Minutos Jugados": [],
    "Tarjetas Amarillas": [],
    "Tarjetas Rojas": []
}

# Recorrer las filas del cuerpo de la tabla y extraer datos
for row in table.find('tbody').find_all('tr'):
    # Extraer el nombre del jugador
    jugador = row.find('td', {'class': 'data-name'}).text.strip()
    players_data["Jugador"].append(jugador)

    # Extraer cada una de las estadísticas y añadirlas a la lista correspondiente
    players_data["Goles"].append(row.find('td', {'class': 'data-g'}).text.strip())
    players_data["Asistencias"].append(row.find('td', {'class': 'data-a'}).text.strip())
    players_data["Disparos Totales"].append(row.find('td', {'class': 'data-dt'}).text.strip())
    players_data["Disparos a Portería"].append(row.find('td', {'class': 'data-dp'}).text.strip())
    players_data["Disparos fuera del Area"].append(row.find('td', {'class': 'data-df'}).text.strip())
    players_data["Vallas Invictas"].append(row.find('td', {'class': 'data-vi'}).text.strip())
    players_data["Faltas Cometidas"].append(row.find('td', {'class': 'data-fc'}).text.strip())
    players_data["Faltas Recibidas"].append(row.find('td', {'class': 'data-fr'}).text.strip())
    players_data["Minutos Jugados"].append(row.find_all('td', {'class': 'data-ta'})[0].text.strip())
    players_data["Tarjetas Amarillas"].append(row.find_all('td', {'class': 'data-ta'})[1].text.strip())
    players_data["Tarjetas Rojas"].append(row.find('td', {'class': 'data-tr'}).text.strip())

# Convertir los datos a un DataFrame de Pandas para visualizar o exportar
df = pd.DataFrame(players_data)
#print(df)

# Guardar los datos en un archivo CSV
df.to_csv('datos_jugadores.csv', index=False)

dfgoles = df.sort_values(by='Goles', ascending=False).head(5)
print(dfgoles)


dfmg = df.sort_values(by=['Minutos Jugados', 'Goles'], ascending=[False, False]).head(10)
print(dfmg)

dftr = df.sort_values(by=['Tarjetas Amarillas', 'Tarjetas Rojas'], ascending=[False, False]).head(10)
print(dftr)
# Out:
#                                Jugador Goles Asistencias Disparos Totales  \
# 200  Rolando Manrique Blackburn Ortega     8           2               25
# 169                   Agustín Auzmendi     7           0               18
# 114       Jorge Renan Benguche Ramirez     6           0               13
# 14        Roberto Ramon Moreira Aldana     6           0               12
# 28                Jose Mario Pinto Paz     4           4               20
#
#     Disparos a Portería Disparos fuera del Area Vallas Invictas  \
# 200                  13                       0               -
# 169                  12                       0               -
# 114                   8                       0               -
# 14                    8                       0               -
# 28                   10                       0               -
#
#     Faltas Cometidas Faltas Recibidas Minutos Jugados Tarjetas Amarillas  \
# 200                8               29            1056                  0
# 169                3               12             723                  0
# 114               12                8             465                  1
# 14                12               14             884                  2
# 28                19               18            1058                  1
#
#     Tarjetas Rojas
# 200              0
# 169              0
# 114              0
# 14               1
# 28               0
#                                 Jugador Goles Asistencias Disparos Totales  \
# 29           Jorge Daniel Alvarez Rodas     2           1               11
# 81             Nelson Jose Muñoz Garcia     0           0                1
# 180          Jonathan Joel Ucles Romero     0           0                0
# 176       Jose Julian Martinez Crisanto     0           2                0
# 208     Allan Alexander Banegas Murillo     0           1                4
# 207                      Darixon Vuelto     3           2               11
# 55         Marlon Roberto Ramirez Arauz     1           3                7
# 37       Jhow Hendric Benavidez Banegas     1           2               14
# 34       Josman Alexander Figueroa Arzu     0           1                2
# 25   Edwin Alexander Rodriguez Castillo     2           3               27
#
#     Disparos a Portería Disparos fuera del Area Vallas Invictas  \
# 29                    4                       0               -
# 81                    1                       0               -
# 180                   0                       0               -
# 176                   0                       0               -
# 208                   2                       0               -
# 207                   3                       0               -
# 55                    5                       0               -
# 37                    4                       0               -
# 34                    1                       0               -
# 25                   14                       0               -
#
#     Faltas Cometidas Faltas Recibidas Minutos Jugados Tarjetas Amarillas  \
# 29                11               12             993                  2
# 81                 8                6             990                  6
# 180                2                0              99                  1
# 176               17               19             981                  1
# 208               18               14             978                  5
# 207               13               10             973                  1
# 55                17               22             966                  2
# 37                 6               15             960                  4
# 34                 1                2              96                  0
# 25                28               17             927                  3
#
#     Tarjetas Rojas
# 29               0
# 81               0
# 180              0
# 176              0
# 208              0
# 207              0
# 55               0
# 37               0
# 34               0
# 25               0
#                              Jugador Goles Asistencias Disparos Totales  \
# 201           Daniel Aparicio Jacobs     1           0                2
# 183      Sebastian Hernandez Le Pors     0           0                0
# 26      Jhonatan Josue Paz Hernandez     0           0                1
# 45      Junior Jose Garcia Contreras     0           0                4
# 81          Nelson Jose Muñoz Garcia     0           0                1
# 215          Henry Josue Gomez Lopez     0           0                4
# 120     Anfronit Kriss Tatum Ferrera     0           0                1
# 104      Hector Javier Aranda Medina     2           3               10
# 118      Luis Orlando Hurtado Cuesta     3           1               15
# 208  Allan Alexander Banegas Murillo     0           1                4
#
#     Disparos a Portería Disparos fuera del Area Vallas Invictas  \
# 201                   1                       0               -
# 183                   0                       0               -
# 26                    0                       0               -
# 45                    0                       0               -
# 81                    1                       0               -
# 215                   1                       0               -
# 120                   1                       0               -
# 104                   3                       0               -
# 118                   3                       0               -
# 208                   2                       0               -
#
#     Faltas Cometidas Faltas Recibidas Minutos Jugados Tarjetas Amarillas  \
# 201               19               10            1034                  7
# 183               12                1             810                  6
# 26                 8                8             855                  6
# 45                 8                9             873                  6
# 81                 8                6             990                  6
# 215               12               14             625                  6
# 120                9                5             468                  5
# 104               14               12             831                  5
# 118                4               19             827                  5
# 208               18               14             978                  5
#
#     Tarjetas Rojas
# 201              0
# 183              1
# 26               0
# 45               0
# 81               0
# 215              0
# 120              1
# 104              0
# 118              0
# 208              0
